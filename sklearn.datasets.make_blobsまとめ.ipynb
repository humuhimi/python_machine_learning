# %%
# %matplotlib inline
from matplotlib import rcParams
rcParams.update({'xtick.color':'w','ytick.color':'w','axes.labelcolor':'gold'})
import japanize_matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y =  make_blobs(n_samples=10,centers=3 , n_features= 2,random_state=0)
# center はyに「影響してる

# %%
print(X.shape)
# Out:
# (10, 2)

# %%
len(X) # 数えるときはlen
# Out:
# 10

# %%
y
# Out:
# array([0, 0, 1, 0, 2, 2, 2, 1, 1, 0])

# %%
# from sklearn.datasets.samples_generator import

# %%
from sklearn.datasets.samples_generator import make_blobs
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

X, y = make_blobs(n_features=2, centers=3)
X_train, X_test, y_train, y_test = train_test_split(X, y)
# x_train,X_testはXから、Y_train,y_testはyから生成される。
model = KNeighborsClassifier()
model.fit(X_train, y_train) # train →　target 型を作る

y_pred = model.predict(X_test)

acc = accuracy_score(y_test, y_pred) * 100
print('accuracy: {}%'.format(acc))
X[:10] # 特徴量は上で指定した通り2こ
# Out:
# accuracy: 100.0%
# array([[-7.34692257, -4.12973606],
#        [-6.90120286, -1.3748958 ],
#        [-2.72066336, -8.27410406],
#        [ 5.4187514 ,  3.66594049],
#        [-9.54715018, -2.01689386],
#        [-7.64869037, -2.01858814],
#        [-6.72947493, -1.44732475],
#        [-4.15366203, -6.06752809],
#        [-7.02327347, -2.50875661],
#        [ 4.60823362,  6.30226985]])

# %%
# plot 1 (centers=1)
X, y = make_blobs(n_features=2, centers=1)
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y) # 特徴量1,2
plt.savefig('centers_1.png')
plt.title('centers = 1',color='y')
# Out:
# Text(0.5, 1.0, 'centers = 1')

# %%
# plot 2    ('centers = 2')
X, y = make_blobs(n_features=2, centers=2)
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.title('centers = 2',color='y')
# Out:
# Text(0.5, 1.0, 'centers = 2')

# %%
# plot 3 ('centers = 3')
X, y = make_blobs(n_features=2, centers=3)
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.title('centers = 3',color='y')
# Out:
# Text(0.5, 1.0, 'centers = 3')

# %% [markdown]
# それぞれのセンター毎に分けたブロブ(塊)で生成する
# https://stackoverflow.com/questions/51709878/what-does-n-features-and-centers-parameters-mean-in-make-blobs-in-scikit
